# %% [markdown]
# ![1_opzxrBna63YDbd8_pM5trw.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
AAPL=pd.read_csv("/content/drive/MyDrive/Stocks/AAPL.csv")
AMZN=pd.read_csv("/content/drive/MyDrive/Stocks/AMZN.csv")
TSLA=pd.read_csv("/content/drive/MyDrive/Stocks/TSLA.csv")

# %% [markdown]
# **Data Preprocessing**

# %%
TSLA.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2018-01-02  20.799999  21.474001  20.733334  21.368668  21.368668
# 1  2018-01-03  21.400000  21.683332  21.036667  21.150000  21.150000
# 2  2018-01-04  20.858000  21.236668  20.378668  20.974667  20.974667
# 3  2018-01-05  21.108000  21.149332  20.799999  21.105333  21.105333
# 4  2018-01-08  21.066668  22.468000  21.033333  22.427334  22.427334
#
#       Volume
# 0   65283000
# 1   67822500
# 2  149194500
# 3   68868000
# 4  147891000

# %%
TSLA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   object
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
#  6   Volume     1259 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 69.0+ KB

# %%
TSLA["Date"]=pd.to_datetime(TSLA["Date"])
TSLA=TSLA.astype({"Volume":float})

# %%
TSLA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
#  6   Volume     1259 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 69.0 KB

# %%
TSLA.dropna(inplace=True)

# %%
TSLA=TSLA.sort_values(by='Date',ignore_index=True)

# %%
TSLA=TSLA.reset_index(drop=True)

# %%
TSLA.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean    131.914480   134.953362   128.540340   131.784972   131.784972
# std     118.024908   120.693717   114.974179   117.835854   117.835854
# min      12.073333    12.445333    11.799333    11.931333    11.931333
# 25%      21.060000    21.476001    20.643000    21.078333    21.078333
# 50%      81.431999    81.866669    79.040001    80.577332    80.577332
# 75%     235.556671   239.885002   231.284996   236.125000   236.125000
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  1.259000e+03
# mean   1.324330e+08
# std    9.017629e+07
# min    2.940180e+07
# 25%    7.578000e+07
# 50%    1.016115e+08
# 75%    1.543911e+08
# max    9.140820e+08

# %% [markdown]
# **APPLE**

# %%
AAPL.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2018-01-02  42.540001  43.075001  42.314999  43.064999  40.888062
# 1  2018-01-03  43.132500  43.637501  42.990002  43.057499  40.880943
# 2  2018-01-04  43.134998  43.367500  43.020000  43.257500  41.070831
# 3  2018-01-05  43.360001  43.842499  43.262501  43.750000  41.538441
# 4  2018-01-08  43.587502  43.902500  43.482498  43.587502  41.384155
#
#       Volume
# 0  102223600
# 1  118071600
# 2   89738400
# 3   94640000
# 4   82271200

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   object
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
#  6   Volume     1259 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 69.0+ KB

# %%
AAPL.dropna(inplace=True)

# %%
AAPL["Date"]=pd.to_datetime(AAPL["Date"])
AAPL=AAPL.astype({"Volume":float})

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
#  6   Volume     1259 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 69.0 KB

# %%
AAPL=AAPL.sort_values(by='Date',ignore_index=True)

# %%
AAPL.reset_index(drop=True)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2018-01-02   42.540001   43.075001   42.314999   43.064999   40.888062
# 1    2018-01-03   43.132500   43.637501   42.990002   43.057499   40.880943
# 2    2018-01-04   43.134998   43.367500   43.020000   43.257500   41.070831
# 3    2018-01-05   43.360001   43.842499   43.262501   43.750000   41.538441
# 4    2018-01-08   43.587502   43.902500   43.482498   43.587502   41.384155
# ...         ...         ...         ...         ...         ...         ...
# 1254 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.658981
# 1255 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.831772
# 1256 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.847855
# 1257 2022-12-29  127.989998  130.479996  127.730003  129.610001  129.412415
# 1258 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.731918
#
#            Volume
# 0     102223600.0
# 1     118071600.0
# 2      89738400.0
# 3      94640000.0
# 4      82271200.0
# ...           ...
# 1254   63814900.0
# 1255   69007800.0
# 1256   85438400.0
# 1257   75703700.0
# 1258   77034200.0
#
# [1259 rows x 7 columns]

# %%
AAPL.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean     98.028503    99.217804    96.881497    98.092897    96.668028
# std      46.302471    46.894754    45.688159    46.309891    46.604446
# min      35.994999    36.430000    35.500000    35.547501    34.257286
# 25%      50.956249    51.448750    50.573750    51.022501    49.432793
# 50%      91.279999    92.970001    90.910004    91.632500    90.089386
# 75%     142.760002   144.474998   141.004997   142.864998   141.950348
# max     182.630005   182.940002   179.119995   182.009995   180.683853
#
#              Volume
# count  1.259000e+03
# mean   1.168806e+08
# std    5.504461e+07
# min    3.519590e+07
# 25%    8.014245e+07
# 50%    1.023002e+08
# 75%    1.372052e+08
# max    4.265100e+08

# %% [markdown]
# **AMAZON**

# %%
AMZN.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2018-01-02  58.599998  59.500000  58.525501  59.450500  59.450500  53890000
# 1  2018-01-03  59.415001  60.274502  59.415001  60.209999  60.209999  62176000
# 2  2018-01-04  60.250000  60.793499  60.233002  60.479500  60.479500  60442000
# 3  2018-01-05  60.875500  61.457001  60.500000  61.457001  61.457001  70894000
# 4  2018-01-08  61.799999  62.653999  61.601501  62.343498  62.343498  85590000

# %%
AMZN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   object
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
#  6   Volume     1259 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 69.0+ KB

# %%
AMZN.dropna(inplace=True)

# %%
AMZN["Date"]=pd.to_datetime(AMZN["Date"])
AMZN=AMZN.astype({"Volume":float})

# %%
AMZN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
#  6   Volume     1259 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 69.0 KB

# %%
AMZN = AMZN.sort_values(by = 'Date', ignore_index = True)

# %%
AMZN = AMZN.reset_index(drop = True)

# %%
AMZN.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean    119.895163   121.332617   118.284385   119.812384   119.812384
# std      35.655449    36.039141    35.226090    35.592042    35.592042
# min      58.599998    59.500000    58.525501    59.450500    59.450500
# 25%      89.062252    89.779003    87.965252    88.930500    88.930500
# 50%     107.970001   110.155998   106.294502   107.783501   107.783501
# 75%     158.343750   159.924004   156.199997   158.086998   158.086998
# max     187.199997   188.654007   184.839493   186.570496   186.570496
#
#              Volume
# count  1.259000e+03
# mean   8.655630e+07
# std    4.068149e+07
# min    1.762600e+07
# 25%    5.893800e+07
# 50%    7.499600e+07
# 75%    1.025480e+08
# max    3.113460e+08

# %% [markdown]
# **EDA**

# %%
companies=[TSLA,AAPL,AMZN]
companies_title=["Tesla","Apple","Amazon"]

# %%
plt.figure(figsize=(20,12))
for index,company in enumerate(companies):
  plt.subplot(3, 1, index + 1)
  plt.plot(company["Date"], company["Adj Close"])
  plt.title(companies_title[index])
  plt.ylabel('Adj Close')

# %% [markdown]
# 1)We can see from the above graph that Amazon shares have tremendous decline in the 2020-2021 period.
#
# 2)Telsa shares have tremendous growth in the 2020-2021 period.
#
# If we follow the news, it can be due to
#
# Emission Credit Sales
# Tesla entering the Fast-Growing Compact SUV Market
# Starting production in China

# %%
plt.figure(figsize=(20,12))
for index,company in enumerate(companies):
  plt.subplot(3, 1, index + 1)
  plt.plot(company["Date"], company["Volume"])
  plt.title(companies_title[index])
  plt.ylabel('Volume')

# %% [markdown]
# Now, we have seen the visualizations for the closing price and volume traded each day.

# %% [markdown]
# **Daily return of the stock on average**

# %% [markdown]
# Now that we've done some baseline analysis, let's go ahead and dive a little deeper. We're now going to analyze the risk of the stock. In order to do so we'll need to take a closer look at the daily changes of the stock, and not just its absolute value.

# %%
# pct_change() function calculates the percentage change between the current and a prior element.
# This function by default calculates the percentage change from the immediately previous row. 

for company in companies:
  company["Daily Return"] = company["Adj Close"].pct_change()

# %%
#Distplot is a deprecated function, so to ignore warnings, the filterwarnings function is used.

import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize=(30, 20))
for index, company in enumerate(companies):
  plt.subplot(3,2, index + 1)
  sns.distplot(company["Daily Return"].dropna(), color = "red")
  plt.title(companies_title[index])

# %% [markdown]
# Kurtosis is a statistical measure that defines how heavily the tails of a distribution differ from the tails of a normal distribution. In other words kurtosis identifies whether the tails of a given distribution contain extreme values.

# %%
print("Kurtosis Value")
for index, company in enumerate(companies):
  print(f'{companies_title[index]}: {company["Daily Return"].kurtosis()}')
# Out:
# Kurtosis Value
# Tesla: 3.532138263078571
# Apple: 4.489368639763307
# Amazon: 4.12106780466503

# %% [markdown]
# The above graph and the positive kurtosis value indicate that getting extreme daily return values is rare.

# %% [markdown]
# **the correlation between diffrent stocks closing price**

# %%
# Companies_return contain closing price of all the companies
Companies_returns = pd.DataFrame()
Companies_returns["TSLA"] = TSLA["Adj Close"]
Companies_returns["AAPL"] = AAPL["Adj Close"]
Companies_returns["AMZN"] = AMZN["Adj Close"]
Companies_returns.head()
# Out:
#         TSLA       AAPL       AMZN
# 0  21.368668  40.888062  59.450500
# 1  21.150000  40.880943  60.209999
# 2  20.974667  41.070831  60.479500
# 3  21.105333  41.538441  61.457001
# 4  22.427334  41.384155  62.343498

# %%
# Companies_Daily_returns contains percentage daily returns of all the companies
Companies_Daily_returns = Companies_returns.pct_change()
Companies_Daily_returns.head()
# Out:
#        TSLA      AAPL      AMZN
# 0       NaN       NaN       NaN
# 1 -0.010233 -0.000174  0.012775
# 2 -0.008290  0.004645  0.004476
# 3  0.006230  0.011385  0.016163
# 4  0.062638 -0.003714  0.014425

# %% [markdown]
# Now, let's do a correlation plot, to get actual numerical values for the correlation between the stocks closing price

# %%
sns.heatmap(Companies_returns.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# Finally, let's do a correlation plot, to get actual numerical values for the correlation between the stocks daily returns.

# %%
sns.heatmap(Companies_Daily_returns.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# From the above plot, we can see that apple and amazon had the strongest correlation in stocks daily returns.

# %% [markdown]
# **Risk by investing in a paticular stock**

# %% [markdown]
# There are many ways we can quantify risk, one of the most basic ways using the information we've gathered on daily percentage returns is by comparing the expected return with the standard deviation of the daily returns.

# %%
Returns = Companies_Daily_returns.dropna()

plt.figure(figsize=(20, 5))
plt.scatter(Returns.mean(), Returns.std())
plt.xlabel('Expected return')
plt.ylabel('Risk')

for label, x, y in zip(companies_title, Returns.mean(), Returns.std()):
    plt.annotate(label, xy = (x, y), xytext = (20, 0), textcoords = 'offset points')

# %% [markdown]
# From the above graph, we can see that Tesla has the highest expected returns and the highest risk factor. Amazon has the lowest expected returns and the lowest risk factor. google and apple seems to have same returns.

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)
